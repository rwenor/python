# %%
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("db.sqlite3")
df = pd.read_sql("SELECT * from polls_mn_name", con)

# verify that result of SQL query is stored in the dataframe
print df.head()

# con.close()
# Out:
#     id  mn_Name                       mn_Url
# 0    0     luft                         null
# 1    1      Min  http://rwe1814.asuscomm.com
# 2    2      Din  http://rwe1814.asuscomm.com
# 3  101  Acte AS       http://www.Acte AS.com
# 4  102   Axicon        http://www.Axicon.com
#
# [5 rows x 3 columns]

# %%
df = pd.read_csv("parts-ax200", sep='\t')

# %%
df.head()
# Out:
#    102 Sortering Lage lok  mamut nr                    prod produkt nr  \
# 0  103         1      NaN    101526                                NaN
# 1  104         2      NaN    101527                                NaN
# 2  105         3      NaN    101528                                NaN
# 3  106         4      NaN    101509  se mamut nr? Oppdater til v2.0.1?
# 4  107         5      NaN    101533                                NaN
#
#          levr pro nr leverandør                             beskrivelse  \
# 0            PCM3343        KGS                     PCM-3343 hovedkort
# 1       CFDisk/PCExp        KGS                    CF Disk til PCM-3343
# 2    MSWINXPEMBEDDED        KGS  Windows XP embedded Run-Time lisens UK
# 3  Hamre elektronikk      Hamre                        Axspeed 200 kort
# 4        Part #54444      Xymox                   2x3 Brytere, tastatur
#
#    a pris  ant  Pris                                          Kommentar Behov  \
# 0    2310    1  2310  NB!NB! For Axspeed 200 ikke inkluder 2stk Com ...   150
# 1     605    1   605                                         TS4GCF200I   150
# 2     610    1   610                    lisens  Otto sender nytt Image!   150
# 3    3600    1  3600                                                NaN   150
# 4      80    1    80                             Part #54444 2x3 keypad   150
#
#    Mottatt Best. ant Lager 0  LagerT  LagerJ   LagerB  Reserve
# 0       20         ?       ?     NaN     NaN  #VALUE!  #VALUE! ...
# 1      NaN       NaN       7     NaN     NaN        7     -143 ...
# 2      NaN       NaN       0     NaN     NaN        0     -150 ...
# 3       15        15       0     NaN       3      NaN      NaN ...
# 4      NaN       NaN     220     NaN     NaN      220       70 ...
#
# [5 rows x 25 columns]

# %%
dfl = df.groupby('leverandør').count()
dfl
# Out:
#                    102  Sortering  Lage lok  mamut nr  prod produkt nr  \
# leverandør
# Acte AS              1          1         0         1                0
# Axicon               1          1         0         1                0
# BilXtra Skårer       1          1         0         1                0
# CBK                  1          1         0         1                1
# Craftec              1          1         0         1                1
# Digi-Key             1          1         0         0                0
# Elfa                18         18         0        16                3
# Farnell             15         15         0        12                2
# Hamre                1          1         0         1                1
# KGS                  5          5         0         5                0
# KMV                  2          2         0         2                0
# O.Olsen              2          2         0         1                1
# PCBCart              2          2         0         1                0
# Produktmerking AS    2          2         0         2                2
# RS Comp              3          3         2         3                0
# Tessta               1          1         0         1                1
# Tingstad             1          1         0         1                0
# Unica AS             1          1         0         1                0
# Xymox                1          1         0         1                0
# linkeson (kina)      1          1         0         0                0
#
#                    levr pro nr  leverandør  beskrivelse  a pris  ant  Pris  \
# leverandør
# Acte AS                      1           1            1       1    1     1
# Axicon                       0           1            1       0    0     1
# BilXtra Skårer               1           1            1       1    1     1
# CBK                          1           1            1       1    1     1
# Craftec                      1           1            1       1    1     1
# Digi-Key                     1           1            1       0    1     1
# Elfa                        18          18           18      17   18    17
# Farnell                     15          15           15      14   15    15
# Hamre                        1           1            1       1    1     1
# KGS                          5           5            5       3    5     5
# KMV                          2           2            2       2    2     2
# O.Olsen                      1           2            2       0    2     2
# PCBCart                      2           2            2       2    2     2
# Produktmerking AS            2           2            2       1    2     1
# RS Comp                      3           3            3       3    3     3
# Tessta                       0           1            1       1    1     1
# Tingstad                     1           1            1       1    1     1
# Unica AS                     1           1            1       1    1     1
# Xymox                        1           1            1       1    1     1
# linkeson (kina)              0           1            1       1    1     1
#
#                    Kommentar  Behov  Mottatt  Best. ant  Lager 0  LagerT  \
# leverandør
# Acte AS                    1      1        0          0        1       0
# Axicon                     0      0        0          0        1       0
# BilXtra Skårer             1      1        0          0        0       0
# CBK                        1      1        0          0        1       0
# Craftec                    1      1        0          0        1       0
# Digi-Key                   1      1        0          0        1       0
# Elfa                      18     17        0          0       14       0
# Farnell                   15     15        0          0       13       0
# Hamre                      0      1        1          1        1       0
# KGS                        5      5        1          1        3       0
# KMV                        2      2        0          0        2       0
# O.Olsen                    2      2        0          0        1       0
# PCBCart                    2      2        0          2        2       0
# Produktmerking AS          2      2        0          0        2       0
# RS Comp                    3      3        0          0        3       0
# Tessta                     0      1        0          0        1       0
# Tingstad                   1      1        0          0        1       0
# Unica AS                   1      1        0          0        1       0
# Xymox                      1      1        0          0        1       0
# linkeson (kina)            1      1        1          1        1       0
#
#                    LagerJ  LagerB  Reserve
# leverandør
# Acte AS                 0       1        1 ...
# Axicon                  0       0        0 ...
# BilXtra Skårer          0       1        1 ...
# CBK                     0       1        1 ...
# Craftec                 0       1        1 ...
# Digi-Key                0       1        1 ...
# Elfa                    0      17       17 ...
# Farnell                 0      12       12 ...
# Hamre                   1       0        0 ...
# KGS                     0       5        5 ...
# KMV                     0       2        2 ...
# O.Olsen                 0       2        2 ...
# PCBCart                 0       2        2 ...
# Produktmerking AS       0       2        2 ...
# RS Comp                 0       3        3 ...
# Tessta                  0       1        1 ...
# Tingstad                0       1        1 ...
# Unica AS                0       1        1 ...
# Xymox                   0       1        1 ...
# linkeson (kina)         0       1        1 ...
#
# [20 rows x 25 columns]

# %%
#print dfl.ix[5]

#for row in dfl:
#    print row
for i in dfl.index:
    print "add_mn_name('"+ dfl.ix[i].name +"')"
# Out:
# add_mn_name('Acte AS')
# add_mn_name('Axicon')
# add_mn_name('BilXtra Skårer')
# add_mn_name('CBK')
# add_mn_name('Craftec')
# add_mn_name('Digi-Key')
# add_mn_name('Elfa')
# add_mn_name('Farnell')
# add_mn_name('Hamre')
# add_mn_name('KGS')
# add_mn_name('KMV')
# add_mn_name('O.Olsen')
# add_mn_name('PCBCart')
# add_mn_name('Produktmerking AS')
# add_mn_name('RS Comp')
# add_mn_name('Tessta')
# add_mn_name('Tingstad')
# add_mn_name('Unica AS')
# add_mn_name('Xymox')
# add_mn_name('linkeson (kina)')

# %%
nr = 101
for i in dfl.index:
    print str(nr) +'\t'+ dfl.ix[i].name +'\thttp://www.'+ dfl.ix[i].name +'.com'  
    nr += 1
# Out:
# 101	Acte AS	http://www.Acte AS.com
# 102	Axicon	http://www.Axicon.com
# 103	BilXtra Skårer	http://www.BilXtra Skårer.com
# 104	CBK	http://www.CBK.com
# 105	Craftec	http://www.Craftec.com
# 106	Digi-Key	http://www.Digi-Key.com
# 107	Elfa	http://www.Elfa.com
# 108	Farnell	http://www.Farnell.com
# 109	Hamre	http://www.Hamre.com
# 110	KGS	http://www.KGS.com
# 111	KMV	http://www.KMV.com
# 112	O.Olsen	http://www.O.Olsen.com
# 113	PCBCart	http://www.PCBCart.com
# 114	Produktmerking AS	http://www.Produktmerking AS.com
# 115	RS Comp	http://www.RS Comp.com
# 116	Tessta	http://www.Tessta.com
# 117	Tingstad	http://www.Tingstad.com
# 118	Unica AS	http://www.Unica AS.com
# 119	Xymox	http://www.Xymox.com
# 120	linkeson (kina)	http://www.linkeson (kina).com
